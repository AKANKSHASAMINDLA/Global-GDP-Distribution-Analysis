# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("GDP - HW4 (1).csv")

# %%
df
# Out:
#          Country  Country Code          2000          2001          2002  \
# 0           Aruba          ABW  33120.054180  32117.912320  30862.222690
# 1     Afghanistan          AFG           NaN           NaN    839.485886
# 2          Angola          AGO   3097.307292   3191.266323   3564.096026
# 3         Albania          ALB   3861.334172   4301.352799   4661.371553
# 4      Arab World          ARB   9415.632618   9584.108301   9581.797143
# ..            ...          ...           ...           ...           ...
# 255        Kosovo          XKX   3688.088054   4782.379635   4820.697450
# 256   Yemen, Rep.          YEM   3181.383522   3278.903531   3363.240378
# 257  South Africa          ZAF   7719.255957   7994.262425   8315.442736
# 258        Zambia          ZMB   1691.967387   1773.963693   1835.247757
# 259      Zimbabwe          ZWE   2344.271146   2421.530752   2235.360895
#
#              2003          2004          2005          2006          2007  \
# ...

# %%
# Define year columns (from 2000 to 2010)
year_columns = df.columns[2:]  # skipping 'Country' and 'Country Code'

# Step 1: Remove countries where all GDP values are missing
df = df.dropna(subset=year_columns, how='all')

# %%
df.shape
# Out:
# (241, 13)

# %%
df
# Out:
#          Country  Country Code          2000          2001          2002  \
# 0           Aruba          ABW  33120.054180  32117.912320  30862.222690
# 1     Afghanistan          AFG           NaN           NaN    839.485886
# 2          Angola          AGO   3097.307292   3191.266323   3564.096026
# 3         Albania          ALB   3861.334172   4301.352799   4661.371553
# 4      Arab World          ARB   9415.632618   9584.108301   9581.797143
# ..            ...          ...           ...           ...           ...
# 255        Kosovo          XKX   3688.088054   4782.379635   4820.697450
# 256   Yemen, Rep.          YEM   3181.383522   3278.903531   3363.240378
# 257  South Africa          ZAF   7719.255957   7994.262425   8315.442736
# 258        Zambia          ZMB   1691.967387   1773.963693   1835.247757
# 259      Zimbabwe          ZWE   2344.271146   2421.530752   2235.360895
#
#              2003          2004          2005          2006          2007  \
# ...

# %%
# Step 2: Fill missing GDP values with the mean GDP for that country
def fill_missing_with_country_mean(row):
    gdp_values = row[year_columns]
    mean_value = gdp_values.mean(skipna=True)
    return gdp_values.fillna(mean_value)

df[year_columns] = df.apply(fill_missing_with_country_mean, axis=1)
# Out:
# /var/folders/41/l3bzp_qs7sg9pqvnnlx00zsr0000gn/T/ipykernel_19423/3191073533.py:5: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return gdp_values.fillna(mean_value)
# /var/folders/41/l3bzp_qs7sg9pqvnnlx00zsr0000gn/T/ipykernel_19423/3191073533.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[year_columns] = df.apply(fill_missing_with_country_mean, axis=1)

# %%
df
# Out:
#          Country  Country Code          2000          2001          2002  \
# 0           Aruba          ABW  33120.054180  32117.912320  30862.222690
# 1     Afghanistan          AFG   1123.409196   1123.409196    839.485886
# 2          Angola          AGO   3097.307292   3191.266323   3564.096026
# 3         Albania          ALB   3861.334172   4301.352799   4661.371553
# 4      Arab World          ARB   9415.632618   9584.108301   9581.797143
# ..            ...          ...           ...           ...           ...
# 255        Kosovo          XKX   3688.088054   4782.379635   4820.697450
# 256   Yemen, Rep.          YEM   3181.383522   3278.903531   3363.240378
# 257  South Africa          ZAF   7719.255957   7994.262425   8315.442736
# 258        Zambia          ZMB   1691.967387   1773.963693   1835.247757
# 259      Zimbabwe          ZWE   2344.271146   2421.530752   2235.360895
#
#              2003          2004          2005          2006          2007  \
# ...

# %%
df.isnull().sum()
# Out:
# Country         0
# Country Code    0
# 2000            0
# 2001            0
# 2002            0
# 2003            0
# 2004            0
# 2005            0
# 2006            0
# 2007            0
# 2008            0
# 2009            0
# 2010            0
# dtype: int64

# %%
df.to_csv("gdp_latest_data.csv")
